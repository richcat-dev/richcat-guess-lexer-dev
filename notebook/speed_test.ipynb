# %% [markdown]
# # 前準備

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import matplotlib.pyplot as plt
from glob import glob

from test_tools import TestExecutor

# %%
test_executor = TestExecutor(n_trails=1000)

# %%
filepath_list = sorted(glob(f'{os.environ["HOME"]}/debug/*'))

# %% [markdown]
# # 実験

# %% [markdown]
# ## `Syntax.from_path()` を利用する

# %%
from target_functions.func_from_path import TPFromPath

# %%
tp_from_path = TPFromPath()

# %%
result_dict = test_executor.exec_test(
    tp_from_path.exec_main_process, 
    filepath_list
)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
test_executor.show_result(result_dict).loc['mean':].plot(
    title='TPFromPath',
    xlabel='Statistics',
    ylabel='Time [s]',
    kind='bar', 
    figsize=(10, 10)
)

plt.legend(bbox_to_anchor=(1.45, 1), loc='upper right')

# %% [markdown]
# ## 辞書を使うパターン

# %%
from target_functions.func_lexer_dict import TPLexerDict

# %%
tp_lexer_dict = TPLexerDict()

# %%
result_dict = test_executor.exec_test(
    tp_lexer_dict.exec_main_process, 
    filepath_list
)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
test_executor.show_result(result_dict).loc['mean':].plot(
    title='TPLexerDict',
    xlabel='Statistics',
    ylabel='Time [s]',
    kind='bar', 
    figsize=(10, 10)
)

plt.legend(bbox_to_anchor=(1.45, 1), loc='upper right')
